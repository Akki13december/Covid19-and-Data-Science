# %%
pip install numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 8.4 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 8.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 34.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 12.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.5 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 7.6 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 13.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 7.3 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 8.2 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import pandas as pd
sns.set()

# %%
dataset1 = pd.read_csv("Covid_19_India 3.csv")

# %%
dataset2 = pd.read_csv("StatewiseTestingDetails.csv")

# %%
dataset1.head()
# Out:
#     Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0  9265  09/12/20  8:00 AM                Delhi                       -
# 1  9206  07/12/20  8:00 AM          Maharashtra                       -
# 2  9267  09/12/20  8:00 AM              Gujarat                       -
# 3  9268  09/12/20  8:00 AM              Haryana                       -
# 4  9271  09/12/20  8:00 AM            Jharkhand                       -
#
#   ConfirmedForeignNational    Cured  Deaths  Confirmed
# 0                        -   565039    9763    1852266
# 1                        -  1581373   47734    1652266
# 2                        -   203111    4110    1452265
# 3                        -   232108    2624    1352264
# 4                        -   107898     988    1052262

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter
from matplotlib import pyplot
import warnings; warnings.simplefilter('ignore')
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
dataset2.head()
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
dataset2.isnull().sum()
# Out:
# Date               0
# State              0
# TotalSamples       0
# Negative        3772
# Positive        3200
# dtype: int64

# %%
dataset1.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
dataset2.Negative = dataset2.Negative.fillna('0') 
dataset2.Positive = dataset2.Positive.fillna('0')

# %%
dataset2.head()
# Out:
#          Date                        State  TotalSamples Negative Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210     12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0        0     27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0        0     33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0        0     33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0        0     33.0

# %%
dataset1['State/UnionTerritory'].unique()
# Out:
# array(['Delhi', 'Maharashtra', 'Gujarat', 'Haryana', 'Jharkhand',
#        'Madhya Pradesh', 'Maharashtra***', 'Karnataka', 'Andhra Pradesh',
#        'Tamil Nadu', 'Kerala', 'Uttar Pradesh', 'West Bengal', 'Odisha',
#        'Rajasthan', 'Telengana', 'Chhattisgarh', 'Bihar', 'Assam',
#        'Punjab', 'Punjab***', 'Jammu and Kashmir', 'Uttarakhand',
#        'Telengana***', 'Telangana', 'Telangana***', 'Goa',
#        'Himachal Pradesh', 'Puducherry', 'Tripura', 'Manipur',
#        'Chandigarh', 'Arunachal Pradesh', 'Chandigarh***', 'Meghalaya',
#        'Nagaland', 'Cases being reassigned to states', 'Ladakh',
#        'Andaman and Nicobar Islands', 'Sikkim', 'Mizoram',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Unassigned',
#        'Dadar Nagar Haveli', 'Daman & Diu'], dtype=object)

# %%
dataset1.rename(columns = {'State/UnionTerritory':'State'},inplace=True)

# %%
dataset1
# Out:
#        Sno      Date     Time        State ConfirmedIndianNational  \
# 0     9265  09/12/20  8:00 AM        Delhi                       -
# 1     9206  07/12/20  8:00 AM  Maharashtra                       -
# 2     9267  09/12/20  8:00 AM      Gujarat                       -
# 3     9268  09/12/20  8:00 AM      Haryana                       -
# 4     9271  09/12/20  8:00 AM    Jharkhand                       -
# ...    ...       ...      ...          ...                     ...
# 9286  1048  17/04/20  5:00 PM     Nagaland                       -
# 9287  1081  18/04/20  5:00 PM     Nagaland                       -
# 9288  1114  19/04/20  5:00 PM     Nagaland                       -
# 9289  1147  20/04/20  5:00 PM     Nagaland                       -
# 9290  1180  21/04/20  5:00 PM     Nagaland                       -
#
#      ConfirmedForeignNational    Cured  Deaths  Confirmed
# 0                           -   565039    9763    1852266
# ...

# %%
dataset1['State'].unique()
# Out:
# array(['Delhi', 'Maharashtra', 'Gujarat', 'Haryana', 'Jharkhand',
#        'Madhya Pradesh', 'Maharashtra***', 'Karnataka', 'Andhra Pradesh',
#        'Tamil Nadu', 'Kerala', 'Uttar Pradesh', 'West Bengal', 'Odisha',
#        'Rajasthan', 'Telengana', 'Chhattisgarh', 'Bihar', 'Assam',
#        'Punjab', 'Punjab***', 'Jammu and Kashmir', 'Uttarakhand',
#        'Telengana***', 'Telangana', 'Telangana***', 'Goa',
#        'Himachal Pradesh', 'Puducherry', 'Tripura', 'Manipur',
#        'Chandigarh', 'Arunachal Pradesh', 'Chandigarh***', 'Meghalaya',
#        'Nagaland', 'Cases being reassigned to states', 'Ladakh',
#        'Andaman and Nicobar Islands', 'Sikkim', 'Mizoram',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Unassigned',
#        'Dadar Nagar Haveli', 'Daman & Diu'], dtype=object)

# %%
dataset1=dataset1.replace('Telengana','Telangana')
dataset1=dataset1.replace('Telengana***','Telangana')
dataset1=dataset1.replace('Telangana***','Telangana')
dataset1=dataset1.replace('Maharashtra***','Maharashtra')
dataset1=dataset1.replace('Chandigarh***','Chandigarh')
dataset1=dataset1.replace('Punjab***','Punjab')

# %%
dropn_indexnames =dataset1[(dataset1['State'] == 'Cases being reassigned to states')].index 
dataset1.drop(dropn_indexnames,inplace=True)

# %%
dataset1['State'].unique()
# Out:
# array(['Delhi', 'Maharashtra', 'Gujarat', 'Haryana', 'Jharkhand',
#        'Madhya Pradesh', 'Karnataka', 'Andhra Pradesh', 'Tamil Nadu',
#        'Kerala', 'Uttar Pradesh', 'West Bengal', 'Odisha', 'Rajasthan',
#        'Telangana', 'Chhattisgarh', 'Bihar', 'Assam', 'Punjab',
#        'Jammu and Kashmir', 'Uttarakhand', 'Goa', 'Himachal Pradesh',
#        'Puducherry', 'Tripura', 'Manipur', 'Chandigarh',
#        'Arunachal Pradesh', 'Meghalaya', 'Nagaland', 'Ladakh',
#        'Andaman and Nicobar Islands', 'Sikkim', 'Mizoram',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Unassigned',
#        'Dadar Nagar Haveli', 'Daman & Diu'], dtype=object)

# %%
dataset1.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State                       0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
dataset2.isnull().sum()
# Out:
# Date            0
# State           0
# TotalSamples    0
# Negative        0
# Positive        0
# dtype: int64

# %%
dataset1.describe()
# Out:
#                Sno         Cured        Deaths     Confirmed
# count  9231.000000  9.231000e+03   9231.000000  9.231000e+03
# mean   4655.470372  7.954798e+04   1502.338425  8.750919e+04
# std    2687.877049  1.930816e+05   4732.788069  1.824440e+05
# min       1.000000  0.000000e+00      0.000000  0.000000e+00
# 25%    2314.500000  1.710000e+02      2.000000  4.260000e+02
# 50%    4676.000000  4.437000e+03     69.000000  6.255000e+03
# 75%    6983.500000  5.889750e+04    932.500000  7.724650e+04
# max    9291.000000  1.581373e+06  47827.000000  1.852266e+06

# %%
df = dataset1.head(5)
df1 = df.sort_values(by='Confirmed', ascending=False).head(5)

# %%
dataset2 = dataset2.astype({'Positive': 'int32'})

# %%
dataset2.dtypes
# Out:
# Date             object
# State            object
# TotalSamples    float64
# Negative         object
# Positive          int32
# dtype: object

# %%
x = ['Deaths', 'Cured', 'Confirmed', 'Active']
h = [289, 1490, 28, 1462]
c = ['black', 'yellow', 'red', 'blue']
plt.bar(x, height = h, color = c)
plt.show()

# %%
a4_dims = (13, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
barp = sns.barplot(data=df1,x='State',y='Confirmed',ax=ax)
barp.set_yticklabels(labels=(barp.get_yticks()*1).astype(int))
plt.show()

# %%
df1['Fatality-Ratio'] = df1['Deaths']/df1['Confirmed']
a4_dims = (15, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
plt.title('Death-Ratio of Top 5 Contaminated States',size=15)
sns.pointplot(data=df1,x='State',y='Fatality-Ratio',ax=ax,color='Black')
plt.show()

# %%
df1['Cure-Ratio'] = df1['Cured']/df1['Confirmed']
a4_dims = (15, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
plt.title('Cure-Ratio of Top 5 Contaminated States',size=15)
sns.pointplot(data=df1,x='State',y='Cure-Ratio',ax=ax,color='Yellow')
plt.show()

# %%
Delhi = dataset1[dataset1.State == 'Delhi']
Delhi
# Out:
#        Sno      Date     Time  State ConfirmedIndianNational  \
# 0     9265  09/12/20  8:00 AM  Delhi                       -
# 352   5695  29/08/20  8:00 AM  Delhi                       -
# 353   5730  30/08/20  8:00 AM  Delhi                       -
# 354   5765  31/08/20  8:00 AM  Delhi                       -
# 355   5800  01/09/20  8:00 AM  Delhi                       -
# ...    ...       ...      ...    ...                     ...
# 8631    72  08/03/20  6:00 PM  Delhi                       3
# 8722    46  05/03/20  6:00 PM  Delhi                       2
# 9034    35  02/03/20  6:00 PM  Delhi                       1
# 9035    39  03/03/20  6:00 PM  Delhi                       1
# 9036    43  04/03/20  6:00 PM  Delhi                       1
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# 0                           -  565039    9763    1852266
# 352                         -  151473    4389     597112
# 353                         -  152922    4404     597112
# ...

# %%
req = Delhi[Delhi['Date'].isin(['09/03/20','09/04/20','09/05/20','09/06/20','09/07/20','09/08/20','09/09/20','09/10/20','09/11/20','09/12/20'])]

# %%
req
# Out:
#        Sno      Date     Time  State ConfirmedIndianNational  \
# 0     9265  09/12/20  8:00 AM  Delhi                       -
# 363   6080  09/09/20  8:00 AM  Delhi                       -
# 393   7130  09/10/20  8:00 AM  Delhi                       -
# 424   8215  09/11/20  8:00 AM  Delhi                       -
# 1667  4995  09/08/20  8:00 AM  Delhi                       -
# 2021  3900  09/07/20  8:00 AM  Delhi                       -
# 3128  2819  09/06/20  8:00 AM  Delhi                       -
# 4638  1746  09/05/20  8:00 AM  Delhi                       -
# 6741   778  09/04/20  5:00 PM  Delhi                       -
# 8584    85  09/03/20  6:00 PM  Delhi                       4
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# 0                           -  565039    9763    1852266
# 363                         -  170140    4618     597112
# 393                         -  272948    5653     597112
# 424                         -  389683    6989     597112
# ...

# %%
a4_dims = (13, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
pp = sns.lineplot(data=req,x='Date',y='Confirmed',ax=ax,color='orange')
pp = sns.lineplot(data=req,x='Date',y='Cured',ax=ax,color='green')
pp = sns.lineplot(data=req,x='Date',y='Deaths',ax=ax,color='red')
pp.set_yticklabels(labels=(pp.get_yticks()*1).astype(int))
fig.legend(labels=['Confirmed','Cured','Deaths'])
plt.title('Vulnerability summary of Delhi',size=15)
plt.show()

# %%
test_delhi = dataset2[dataset2.State == 'Delhi']
reqe = test_delhi[test_delhi['Date'].isin(['2020-04-05','2020-05-05','2020-06-05','2020-07-05','2020-08-05','2020-09-05','2020-10-05','2020-11-05','2020-12-05'])]
a4_dims = (13, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
lp = sns.lineplot(x='Date',y='TotalSamples',data=reqe,ax=ax,color='green')
lp.set_yticklabels(labels=(lp.get_yticks()*1).astype(int))
plt.title('Testing in Delhi',size=15)
plt.show()

# %%
a4_dims = (13, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
reqe['positive/samples'] = (reqe['Positive']/reqe['TotalSamples'])
df =reqe.iloc[1:7]
sns.lineplot(x='Date',y='positive/samples',ax=ax,data=df)
plt.title('Positive Cases per Samples in Delhi',size=15)
plt.show()

# %%
req = dataset1[dataset1['Date'].isin(['09/03/20','09/04/20','09/05/20','09/06/20','09/07/20','09/08/20','09/09/20','09/10/20','09/11/20','09/12/20'])]
a4_dims = (13, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
lp= sns.pointplot(x='Date',y='Confirmed',hue='State',ax=ax,data=req,palette='tab20')
lp.set_yticklabels(labels=(lp.get_yticks()*1).astype(int))
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
plt.title('Confirmed Cases of All States by Date',size=15)
plt.show()

# %%
reqe = dataset2[dataset2['Date'].isin(['2020-06-05','2020-07-05','2020-08-05','2020-09-05','2020-10-05','2020-11-05','2020-12-05'])]
a4_dims = (13, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
lp= sns.lineplot(x='Date',y='TotalSamples',hue='State',ax=ax,data=reqe,palette='tab20')
lp.set_yticklabels(labels=(lp.get_yticks()*1).astype(int))
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
plt.title('Testing Details trend of All States by Date',size=15)
plt.show()

# %%
a4_dims = (13, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
pp = sns.lineplot(data=req,x='Date',y='Confirmed',ax=ax,color='orange')
pp = sns.lineplot(data=req,x='Date',y='Cured',ax=ax,color='Green')
pp = sns.lineplot(data=req,x='Date',y='Deaths',ax=ax,color='Red')
pp.set_yticklabels(labels=(pp.get_yticks()*1).astype(int))
fig.legend(labels=['Confirmed','Cured','Deaths'])
plt.title('Vulnerability summary of Covid-19 by Date',size=15)
plt.show()

# %%
df1['Fatality-Ratio'] = df1['Deaths']/df1['Confirmed']
a4_dims = (15, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
plt.title('Death-Ratio of Top 5 Contaminated States',size=15)
sns.pointplot(data=df1,x='State',y='Fatality-Ratio',ax=ax,color='Black')
plt.show()

# %%
pip install scikit-learn scipy matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 7.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 25.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import metrics

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
Accuracy = metrics.accuracy_score(actual, predicted)

# %%
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

Accuracy = metrics.accuracy_score(actual, predicted)

print(Accuracy)
# Out:
# 0.822
